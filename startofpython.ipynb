# %%
#FIRST PROGRAM
print("hello world")
# Out:
# hello world

# %%
#VARIABLES AND DATA TYPES
name = "pooji" #string--double quotes should be there and single quotes also be accepted
name2 = 'maari'
age = 40 #int
marks = 27.8 #float
is_student = True #boolen
print(name,name2)
print(age)
print(marks)
print(is_student)
# Out:
# pooji maari
# 40
# 27.8
# True

# %%
#TYPE CHECK
print(type(name)) #at a same time type cannot be determined for both variables
print(type(age))
print(type(marks))
print(type(is_student))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
#INPUT FROM USER
order = input("enter the food u wanted to order : ")
quantity = input("enter the quantity of the food u wanted to order : ")
print("u ordered:",order)
print("quantity is:", quantity)
#NOTE: INPUT IS ALWAYS COMES AS STRING
# Out:
# enter the food u wanted to order :  PIZZA
# enter the quantity of the food u wanted to order :  2
# u ordered: PIZZA
# quantity is: 2

# %%
age = 20
print(5+age)
# Out:
# 25

# %%
#ADDING NUMBERS
marks = int(input("enter:"))
a = int(input("a:"))
b = int(input("b:"))
print(marks + 20)
print("sum = ",a + b)
# Out:
# enter: 43
# a: 2
# b: 3
# 63
# sum =  5

# %%
#AVG OF NUMS
a = int(input("a:"))
b = int(input("b:"))
c = int(input("c:")) #the operation can be written in print statement and can also be written by creating a variable
#avg = (a+b+c)/3
print("avg = ",(a+b+c)/3)
# Out:
# a: 4
# b: 3
# c: 2
# avg =  3.0

# %%
n = int(input("enter a num:"))
print("square:",n*n)
print("cube:",n*n*n)
# Out:
# enter a num: 4
# square: 16
# cube: 64

# %%
# TYPE CASTING IS IMP THAT THE INPUT FROM USER IS TAKEN AS STRING AND AT THE OUTPUT IT IS GIVEN AS STRING i.e, IF NUMS ARE GIVEN THEY WERE PRINTED 
#OUT AS STRING (1010)
