# %%
#EVEN OR ODD
n = int(input("enter: "))
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter:  7
# odd

# %%
#POSITIVE OR NEGATIVE
n = int(input("enter: "))
if n>0:
    print("positive")
else:
    print("negative")
# Out:
# enter:  -99
# negative

# %%
age = int(input("enter ur age: "))
if age>=18:
    print("congrats u get to vote in elections")
else:
    print("better luck next time")
# Out:
# enter ur age:  13
# better luck next time
